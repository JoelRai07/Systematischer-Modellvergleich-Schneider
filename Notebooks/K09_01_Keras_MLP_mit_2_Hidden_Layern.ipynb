# %% [markdown]
# # K09_01 - Keras MLP mit zwei Hidden Layers
#
# ## Lernziele
# Nach diesem Notebook koennen Sie:
# - ein tieferes MLP mit Keras aufbauen
# - den Unterschied zwischen einem kleinen und einem tieferen Netz
#   **quantitativ** (Parameteranzahl) und **qualitativ** (Lernkurven) einordnen
# - den Begriff **Modellkapazitaet** erklaeren
# - Lernkurven (Train UND Val) korrekt lesen und interpretieren
# - Overfitting an den Lernkurven erkennen
# - einschaetzen, wann mehr Tiefe hilft und wann nicht

# %% [markdown]
# ## Didaktischer Fokus
#
# Leitfrage:
# > Was aendert sich, wenn wir statt eines kleinen Netzes ein Modell
# > mit zwei Hidden Layers verwenden?
#
# Wir beantworten diese Frage auf drei Ebenen:
# 1. **Architektur:** Wie viele Parameter hat jedes Modell?
# 2. **Training:** Wie entwickeln sich Train- und Val-Kurven?
# 3. **Ergebnis:** Unterscheidet sich die finale Test-Accuracy?
#
# ### Warum nicht Iris?
#
# Iris hat nur 150 Samples. Das ist fuer diesen Vergleich zu wenig:
# - Das Validierungsset wird so klein (~24 Samples), dass die Kurven
#   treppenartig springen statt glatt zu verlaufen.
# - Iris ist so einfach, dass das kleine Netz bereits alles loest.
#   Das tiefe Netz hat keinen echten Vorteil – der Vergleich wird sinnlos.
#
# Wir verwenden stattdessen einen **synthetischen Datensatz** mit 2000 Samples
# und 20 Features. Das gibt:
# - genuegend Daten fuer glatte, lesbare Lernkurven
# - eine Aufgabe, die komplex genug ist damit das tiefe Netz einen echten Vorteil zeigt
# - ein sichtbares Overfitting-Signal wenn das Modell zu gross ist

# %% [markdown]
# ## Imports und Reproduzierbarkeit

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(42)

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

import tensorflow as tf
tf.random.set_seed(42)

from tensorflow import keras
from tensorflow.keras import layers

print('Alle Bibliotheken geladen.')
print(f'TensorFlow-Version: {tf.__version__}')
# Out:
# Alle Bibliotheken geladen.
# TensorFlow-Version: 2.19.0

# %% [markdown]
# ## 1. Synthetischen Datensatz erstellen
#
# `make_classification` erzeugt einen kontrollierten Klassifikationsdatensatz.
# Die Parameter bestimmen, wie schwierig die Aufgabe ist:
#
# | Parameter | Bedeutung | Wert hier |
# |---|---|---|
# | `n_samples` | Anzahl Datenpunkte | 2000 |
# | `n_features` | Anzahl Features insgesamt | 20 |
# | `n_informative` | Davon wirklich relevante | 10 |
# | `n_redundant` | Lineare Kombinationen | 5 |
# | `n_classes` | Anzahl Klassen | 3 |
# | `n_clusters_per_class` | Struktur pro Klasse | 2 |
#
# Die 10 nicht-informativen Features und 2 Cluster pro Klasse machen die Aufgabe
# schwierig genug, damit das tiefe Netz einen echten Vorteil gegenueber dem kleinen hat.

# %%
X, y = make_classification(
    n_samples=2000,
    n_features=20,
    n_informative=10,
    n_redundant=5,
    n_classes=3,
    n_clusters_per_class=2,
    random_state=42
)

# One-Hot-Encoding
y_cat = keras.utils.to_categorical(y, num_classes=3)
class_names = ['Klasse 0', 'Klasse 1', 'Klasse 2']

# Klassenverteilung pruefen
unique, counts = np.unique(y, return_counts=True)
print('Datensatz erstellt:')
print(f'  Shape X: {X.shape}')
print(f'  Shape y: {y.shape}')
print('  Klassenverteilung:', dict(zip(unique, counts)))
# Out:
# Datensatz erstellt:
#   Shape X: (2000, 20)
#   Shape y: (2000,)
#   Klassenverteilung: {np.int64(0): np.int64(662), np.int64(1): np.int64(670), np.int64(2): np.int64(668)}

# %% [markdown]
# ## 2. Daten aufteilen und skalieren
#
# Mit 2000 Samples reicht ein einfacher Train/Test-Split.
# Das Validierungsset wird direkt in `model.fit()` via `validation_split=0.2`
# aus den Trainingsdaten erzeugt.
#
# ```
# 2000 Samples
#   x 80% Train+Val = 1600 Trainingsdaten
#     x 20% Val     =  320 Validierungsdaten  <- genuegend fuer glatte Kurven
#     x 80% Train   = 1280 Trainingsdaten
#   x 20% Test      =  400 Testdaten
# ```
#
# 320 Validierungssamples statt 24 bei Iris:
# 1 Fehler = 0.3% statt 4.2% Accuracy-Sprung -> glatte Kurven.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_cat, test_size=0.2, random_state=42, stratify=y
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

print(f'Trainingsdaten (inkl. Val): {X_train_scaled.shape}')
print(f'Testdaten:                  {X_test_scaled.shape}')
print(f'Validierungsdaten (20% v. Train via validation_split): ~{int(X_train.shape[0]*0.2)} Samples')
# Out:
# Trainingsdaten (inkl. Val): (1600, 20)
# Testdaten:                  (400, 20)
# Validierungsdaten (20% v. Train via validation_split): ~320 Samples

# %% [markdown]
# ## 3. Konzept: Warum zwei Hidden Layers?
#
# Jede versteckte Schicht kann andere **Abstraktionsebenen** lernen:
#
# ```
# 1 Hidden Layer:  lernt einfache Merkmalskombinationen
#                  z. B. 'Feature 3 gross UND Feature 7 klein -> Klasse 1'
#
# 2 Hidden Layer:  kann Merkmale hierarchisch kombinieren
#                  Schicht 1: lernt elementare Muster aus den 20 Features
#                  Schicht 2: kombiniert diese Muster zu komplexeren Strukturen
# ```
#
# **Modellkapazitaet** = wie viele Muster ein Netz maximal lernen kann.
# Sie wird hauptsaechlich durch die Anzahl der Parameter bestimmt.
#
# Bei 20 Features und 3 Klassen mit je 2 Clustern ist die Aufgabe
# komplex genug, dass mehr Kapazitaet tatsaechlich hilft.

# %% [markdown]
# ## 4. Zwei Modelle definieren

# %%
# Modell A: kleines Netz - 1 Hidden Layer
model_small = keras.Sequential([
    layers.Input(shape=(20,)),
    layers.Dense(16, activation='relu'),
    layers.Dense(3,  activation='softmax')
], name='kleines_Netz')

model_small.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Modell B: tiefes Netz - 2 Hidden Layers
model_deep = keras.Sequential([
    layers.Input(shape=(20,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(3,  activation='softmax')
], name='tiefes_Netz')

model_deep.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print('=== Kleines Netz ===')
model_small.summary()
print()
print('=== Tiefes Netz ===')
model_deep.summary()
# Out:
# === Kleines Netz ===
# Model: "kleines_Netz"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 387 (1.51 KB)
#  Trainable params: 387 (1.51 KB)
#  Non-trainable params: 0 (0.00 B)
# === Tiefes Netz ===
# Model: "tiefes_Netz"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,523 (13.76 KB)
#  Trainable params: 3,523 (13.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Parameteranzahl im Vergleich
#
# ```
# Kleines Netz (Input: 20 Features):
#   Dense(16):  20 x 16 + 16 Bias  =   336 Parameter
#   Dense(3):   16 x  3 +  3 Bias  =    51 Parameter
#   Gesamt:                             387 Parameter
#
# Tiefes Netz (Input: 20 Features):
#   Dense(64):  20 x 64 + 64 Bias  =  1344 Parameter
#   Dense(32):  64 x 32 + 32 Bias  =  2080 Parameter
#   Dense(3):   32 x  3 +  3 Bias  =    99 Parameter
#   Gesamt:                           3523 Parameter
# ```
#
# Das tiefe Netz hat **~9x mehr Parameter** – deutlich mehr Modellkapazitaet.
# Bei 20 Features und einer komplexen Aufgabe sollte das einen messbaren Unterschied machen.
#
# > **Frage zum Nachdenken:** Fuehren 9x mehr Parameter automatisch
# > zu besserer Accuracy? Die Lernkurven werden es zeigen.

# %% [markdown]
# ## 5. Beide Modelle trainieren
#
# Beide Modelle trainieren mit identischen Hyperparametern.
# `validation_split=0.2` nimmt die letzten 20% der Trainingsdaten als Val.
# Da die Daten vorher per `train_test_split` gemischt wurden, ist das ausreichend.

# %%
EPOCHS     = 100
BATCH_SIZE = 32

history_small = model_small.fit(
    X_train_scaled, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=0.2,
    verbose=2
)

history_deep = model_deep.fit(
    X_train_scaled, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=0.2,
    verbose=2
)

print(f'Training abgeschlossen: {EPOCHS} Epochen, batch_size={BATCH_SIZE}')
# Out:
# Epoch 1/100
# 40/40 - 0s - 11ms/step - accuracy: 0.8687 - loss: 0.3532 - val_accuracy: 0.8062 - val_loss: 0.4843
# Epoch 2/100
# 40/40 - 1s - 14ms/step - accuracy: 0.8695 - loss: 0.3516 - val_accuracy: 0.8062 - val_loss: 0.4840
# Epoch 3/100
# 40/40 - 1s - 15ms/step - accuracy: 0.8695 - loss: 0.3500 - val_accuracy: 0.8062 - val_loss: 0.4842
# Epoch 4/100
# 40/40 - 1s - 17ms/step - accuracy: 0.8695 - loss: 0.3484 - val_accuracy: 0.8062 - val_loss: 0.4840
# Epoch 5/100
# 40/40 - 1s - 15ms/step - accuracy: 0.8703 - loss: 0.3470 - val_accuracy: 0.8094 - val_loss: 0.4838
# Epoch 6/100
# 40/40 - 1s - 14ms/step - accuracy: 0.8711 - loss: 0.3455 - val_accuracy: 0.8094 - val_loss: 0.4837
# Epoch 7/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8695 - loss: 0.3441 - val_accuracy: 0.8094 - val_loss: 0.4834
# Epoch 8/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8711 - loss: 0.3427 - val_accuracy: 0.8094 - val_loss: 0.4835
# Epoch 9/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8727 - loss: 0.3414 - val_accuracy: 0.8094 - val_loss: 0.4833
# Epoch 10/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8719 - loss: 0.3400 - val_accuracy: 0.8125 - val_loss: 0.4833
# Epoch 11/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8719 - loss: 0.3387 - val_accuracy: 0.8125 - val_loss: 0.4833
# Epoch 12/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8719 - loss: 0.3374 - val_accuracy: 0.8156 - val_loss: 0.4833
# Epoch 13/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8734 - loss: 0.3361 - val_accuracy: 0.8156 - val_loss: 0.4837
# Epoch 14/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8750 - loss: 0.3349 - val_accuracy: 0.8156 - val_loss: 0.4838
# Epoch 15/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8758 - loss: 0.3337 - val_accuracy: 0.8156 - val_loss: 0.4839
# Epoch 16/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8758 - loss: 0.3325 - val_accuracy: 0.8156 - val_loss: 0.4838
# Epoch 17/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8750 - loss: 0.3314 - val_accuracy: 0.8156 - val_loss: 0.4840
# Epoch 18/100
# 40/40 - 0s - 7ms/step - accuracy: 0.8758 - loss: 0.3303 - val_accuracy: 0.8156 - val_loss: 0.4841
# Epoch 19/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8766 - loss: 0.3292 - val_accuracy: 0.8125 - val_loss: 0.4844
# Epoch 20/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8773 - loss: 0.3282 - val_accuracy: 0.8125 - val_loss: 0.4851
# Epoch 21/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8773 - loss: 0.3271 - val_accuracy: 0.8125 - val_loss: 0.4852
# Epoch 22/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8797 - loss: 0.3260 - val_accuracy: 0.8125 - val_loss: 0.4855
# Epoch 23/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8805 - loss: 0.3248 - val_accuracy: 0.8156 - val_loss: 0.4859
# Epoch 24/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8805 - loss: 0.3238 - val_accuracy: 0.8156 - val_loss: 0.4859
# Epoch 25/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8813 - loss: 0.3227 - val_accuracy: 0.8156 - val_loss: 0.4862
# Epoch 26/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8820 - loss: 0.3216 - val_accuracy: 0.8156 - val_loss: 0.4868
# Epoch 27/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8820 - loss: 0.3206 - val_accuracy: 0.8094 - val_loss: 0.4875
# Epoch 28/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8828 - loss: 0.3195 - val_accuracy: 0.8094 - val_loss: 0.4879
# Epoch 29/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8844 - loss: 0.3184 - val_accuracy: 0.8094 - val_loss: 0.4882
# Epoch 30/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8859 - loss: 0.3173 - val_accuracy: 0.8062 - val_loss: 0.4885
# Epoch 31/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8852 - loss: 0.3162 - val_accuracy: 0.8062 - val_loss: 0.4889
# Epoch 32/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8844 - loss: 0.3150 - val_accuracy: 0.8062 - val_loss: 0.4894
# Epoch 33/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8852 - loss: 0.3139 - val_accuracy: 0.8062 - val_loss: 0.4897
# Epoch 34/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8852 - loss: 0.3128 - val_accuracy: 0.8031 - val_loss: 0.4898
# Epoch 35/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8875 - loss: 0.3118 - val_accuracy: 0.8000 - val_loss: 0.4898
# Epoch 36/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8867 - loss: 0.3107 - val_accuracy: 0.8000 - val_loss: 0.4898
# Epoch 37/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8859 - loss: 0.3097 - val_accuracy: 0.8031 - val_loss: 0.4900
# Epoch 38/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8852 - loss: 0.3086 - val_accuracy: 0.8031 - val_loss: 0.4899
# Epoch 39/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8867 - loss: 0.3076 - val_accuracy: 0.8031 - val_loss: 0.4898
# Epoch 40/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8891 - loss: 0.3063 - val_accuracy: 0.8031 - val_loss: 0.4899
# Epoch 41/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8883 - loss: 0.3052 - val_accuracy: 0.8000 - val_loss: 0.4898
# Epoch 42/100
# 40/40 - 0s - 8ms/step - accuracy: 0.8883 - loss: 0.3041 - val_accuracy: 0.7969 - val_loss: 0.4895
# Epoch 43/100
# 40/40 - 1s - 15ms/step - accuracy: 0.8891 - loss: 0.3031 - val_accuracy: 0.7969 - val_loss: 0.4894
# Epoch 44/100
# 40/40 - 0s - 7ms/step - accuracy: 0.8891 - loss: 0.3022 - val_accuracy: 0.7969 - val_loss: 0.4894
# Epoch 45/100
# 40/40 - 0s - 6ms/step - accuracy: 0.8891 - loss: 0.3011 - val_accuracy: 0.8000 - val_loss: 0.4893
# Epoch 46/100
# 40/40 - 0s - 6ms/step - accuracy: 0.8883 - loss: 0.3002 - val_accuracy: 0.8031 - val_loss: 0.4894
# Epoch 47/100
# 40/40 - 0s - 6ms/step - accuracy: 0.8891 - loss: 0.2993 - val_accuracy: 0.8094 - val_loss: 0.4893
# Epoch 48/100
# 40/40 - 0s - 8ms/step - accuracy: 0.8898 - loss: 0.2984 - val_accuracy: 0.8094 - val_loss: 0.4891
# Epoch 49/100
# 40/40 - 0s - 7ms/step - accuracy: 0.8898 - loss: 0.2975 - val_accuracy: 0.8094 - val_loss: 0.4895
# Epoch 50/100
# 40/40 - 0s - 7ms/step - accuracy: 0.8914 - loss: 0.2967 - val_accuracy: 0.8094 - val_loss: 0.4896
# Epoch 51/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8914 - loss: 0.2958 - val_accuracy: 0.8094 - val_loss: 0.4892
# Epoch 52/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8914 - loss: 0.2950 - val_accuracy: 0.8094 - val_loss: 0.4896
# Epoch 53/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8914 - loss: 0.2942 - val_accuracy: 0.8062 - val_loss: 0.4900
# Epoch 54/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8906 - loss: 0.2934 - val_accuracy: 0.8062 - val_loss: 0.4902
# Epoch 55/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8898 - loss: 0.2927 - val_accuracy: 0.8031 - val_loss: 0.4903
# Epoch 56/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8898 - loss: 0.2920 - val_accuracy: 0.8031 - val_loss: 0.4907
# Epoch 57/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8898 - loss: 0.2913 - val_accuracy: 0.8031 - val_loss: 0.4909
# Epoch 58/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8898 - loss: 0.2905 - val_accuracy: 0.8062 - val_loss: 0.4910
# Epoch 59/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8914 - loss: 0.2898 - val_accuracy: 0.8062 - val_loss: 0.4913
# Epoch 60/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8914 - loss: 0.2892 - val_accuracy: 0.8062 - val_loss: 0.4915
# Epoch 61/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8914 - loss: 0.2885 - val_accuracy: 0.8062 - val_loss: 0.4918
# Epoch 62/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8914 - loss: 0.2879 - val_accuracy: 0.8062 - val_loss: 0.4921
# Epoch 63/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8930 - loss: 0.2873 - val_accuracy: 0.8062 - val_loss: 0.4925
# Epoch 64/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8922 - loss: 0.2866 - val_accuracy: 0.8094 - val_loss: 0.4932
# Epoch 65/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8930 - loss: 0.2861 - val_accuracy: 0.8125 - val_loss: 0.4931
# Epoch 66/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8930 - loss: 0.2855 - val_accuracy: 0.8094 - val_loss: 0.4937
# Epoch 67/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8938 - loss: 0.2849 - val_accuracy: 0.8094 - val_loss: 0.4941
# Epoch 68/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8945 - loss: 0.2843 - val_accuracy: 0.8094 - val_loss: 0.4948
# Epoch 69/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8938 - loss: 0.2837 - val_accuracy: 0.8125 - val_loss: 0.4952
# Epoch 70/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8945 - loss: 0.2832 - val_accuracy: 0.8125 - val_loss: 0.4960
# Epoch 71/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8969 - loss: 0.2825 - val_accuracy: 0.8125 - val_loss: 0.4965
# Epoch 72/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8969 - loss: 0.2820 - val_accuracy: 0.8125 - val_loss: 0.4974
# Epoch 73/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8984 - loss: 0.2814 - val_accuracy: 0.8125 - val_loss: 0.4979
# Epoch 74/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8984 - loss: 0.2809 - val_accuracy: 0.8125 - val_loss: 0.4985
# Epoch 75/100
# 40/40 - 0s - 7ms/step - accuracy: 0.8984 - loss: 0.2804 - val_accuracy: 0.8125 - val_loss: 0.4992
# Epoch 76/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8992 - loss: 0.2798 - val_accuracy: 0.8125 - val_loss: 0.5000
# Epoch 77/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8992 - loss: 0.2793 - val_accuracy: 0.8125 - val_loss: 0.5003
# Epoch 78/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8992 - loss: 0.2787 - val_accuracy: 0.8125 - val_loss: 0.5011
# Epoch 79/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8984 - loss: 0.2783 - val_accuracy: 0.8125 - val_loss: 0.5017
# Epoch 80/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8977 - loss: 0.2777 - val_accuracy: 0.8125 - val_loss: 0.5024
# Epoch 81/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8984 - loss: 0.2773 - val_accuracy: 0.8125 - val_loss: 0.5031
# Epoch 82/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8984 - loss: 0.2768 - val_accuracy: 0.8094 - val_loss: 0.5040
# Epoch 83/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8984 - loss: 0.2764 - val_accuracy: 0.8094 - val_loss: 0.5048
# Epoch 84/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8992 - loss: 0.2758 - val_accuracy: 0.8094 - val_loss: 0.5051
# Epoch 85/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8992 - loss: 0.2754 - val_accuracy: 0.8094 - val_loss: 0.5059
# Epoch 86/100
# 40/40 - 0s - 3ms/step - accuracy: 0.9000 - loss: 0.2750 - val_accuracy: 0.8094 - val_loss: 0.5065
# Epoch 87/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9000 - loss: 0.2745 - val_accuracy: 0.8094 - val_loss: 0.5072
# Epoch 88/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9000 - loss: 0.2740 - val_accuracy: 0.8094 - val_loss: 0.5077
# Epoch 89/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9000 - loss: 0.2735 - val_accuracy: 0.8062 - val_loss: 0.5089
# Epoch 90/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8992 - loss: 0.2731 - val_accuracy: 0.8094 - val_loss: 0.5092
# Epoch 91/100
# 40/40 - 0s - 3ms/step - accuracy: 0.8992 - loss: 0.2727 - val_accuracy: 0.8125 - val_loss: 0.5100
# Epoch 92/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9000 - loss: 0.2723 - val_accuracy: 0.8125 - val_loss: 0.5111
# Epoch 93/100
# 40/40 - 0s - 3ms/step - accuracy: 0.9016 - loss: 0.2718 - val_accuracy: 0.8156 - val_loss: 0.5116
# Epoch 94/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9000 - loss: 0.2714 - val_accuracy: 0.8156 - val_loss: 0.5121
# Epoch 95/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9008 - loss: 0.2710 - val_accuracy: 0.8156 - val_loss: 0.5126
# Epoch 96/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9016 - loss: 0.2705 - val_accuracy: 0.8125 - val_loss: 0.5132
# Epoch 97/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9016 - loss: 0.2701 - val_accuracy: 0.8156 - val_loss: 0.5139
# Epoch 98/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9008 - loss: 0.2697 - val_accuracy: 0.8125 - val_loss: 0.5146
# Epoch 99/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9023 - loss: 0.2692 - val_accuracy: 0.8125 - val_loss: 0.5152
# Epoch 100/100
# 40/40 - 0s - 3ms/step - accuracy: 0.9016 - loss: 0.2689 - val_accuracy: 0.8094 - val_loss: 0.5159
# Epoch 1/100
# 40/40 - 1s - 29ms/step - accuracy: 0.5133 - loss: 1.0075 - val_accuracy: 0.6313 - val_loss: 0.8705
# Epoch 2/100
# 40/40 - 0s - 4ms/step - accuracy: 0.6602 - loss: 0.8106 - val_accuracy: 0.6812 - val_loss: 0.7475
# Epoch 3/100
# 40/40 - 0s - 4ms/step - accuracy: 0.7195 - loss: 0.6948 - val_accuracy: 0.7156 - val_loss: 0.6721
# Epoch 4/100
# 40/40 - 0s - 4ms/step - accuracy: 0.7711 - loss: 0.6131 - val_accuracy: 0.7563 - val_loss: 0.6223
# Epoch 5/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8000 - loss: 0.5537 - val_accuracy: 0.7719 - val_loss: 0.5862
# Epoch 6/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8141 - loss: 0.5071 - val_accuracy: 0.7906 - val_loss: 0.5591
# Epoch 7/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8359 - loss: 0.4687 - val_accuracy: 0.7937 - val_loss: 0.5377
# Epoch 8/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8445 - loss: 0.4358 - val_accuracy: 0.8062 - val_loss: 0.5212
# Epoch 9/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8602 - loss: 0.4072 - val_accuracy: 0.8156 - val_loss: 0.5075
# Epoch 10/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8680 - loss: 0.3823 - val_accuracy: 0.8250 - val_loss: 0.4979
# Epoch 11/100
# 40/40 - 0s - 4ms/step - accuracy: 0.8758 - loss: 0.3601 - val_accuracy: 0.8250 - val_loss: 0.4897
# Epoch 12/100
# 40/40 - 0s - 10ms/step - accuracy: 0.8836 - loss: 0.3396 - val_accuracy: 0.8219 - val_loss: 0.4844
# Epoch 13/100
# 40/40 - 0s - 7ms/step - accuracy: 0.8938 - loss: 0.3210 - val_accuracy: 0.8250 - val_loss: 0.4795
# Epoch 14/100
# 40/40 - 0s - 7ms/step - accuracy: 0.9016 - loss: 0.3038 - val_accuracy: 0.8250 - val_loss: 0.4766
# Epoch 15/100
# 40/40 - 0s - 7ms/step - accuracy: 0.9125 - loss: 0.2880 - val_accuracy: 0.8250 - val_loss: 0.4747
# Epoch 16/100
# 40/40 - 0s - 7ms/step - accuracy: 0.9180 - loss: 0.2736 - val_accuracy: 0.8250 - val_loss: 0.4736
# Epoch 17/100
# 40/40 - 0s - 7ms/step - accuracy: 0.9203 - loss: 0.2604 - val_accuracy: 0.8281 - val_loss: 0.4721
# Epoch 18/100
# 40/40 - 0s - 7ms/step - accuracy: 0.9266 - loss: 0.2482 - val_accuracy: 0.8250 - val_loss: 0.4720
# Epoch 19/100
# 40/40 - 0s - 7ms/step - accuracy: 0.9305 - loss: 0.2370 - val_accuracy: 0.8219 - val_loss: 0.4723
# Epoch 20/100
# 40/40 - 0s - 7ms/step - accuracy: 0.9375 - loss: 0.2269 - val_accuracy: 0.8219 - val_loss: 0.4726
# Epoch 21/100
# 40/40 - 0s - 6ms/step - accuracy: 0.9391 - loss: 0.2170 - val_accuracy: 0.8281 - val_loss: 0.4753
# Epoch 22/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9430 - loss: 0.2080 - val_accuracy: 0.8250 - val_loss: 0.4760
# Epoch 23/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9484 - loss: 0.1993 - val_accuracy: 0.8281 - val_loss: 0.4787
# Epoch 24/100
# 40/40 - 0s - 3ms/step - accuracy: 0.9508 - loss: 0.1912 - val_accuracy: 0.8219 - val_loss: 0.4796
# Epoch 25/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9523 - loss: 0.1837 - val_accuracy: 0.8250 - val_loss: 0.4819
# Epoch 26/100
# 40/40 - 0s - 3ms/step - accuracy: 0.9539 - loss: 0.1764 - val_accuracy: 0.8250 - val_loss: 0.4839
# Epoch 27/100
# 40/40 - 0s - 3ms/step - accuracy: 0.9555 - loss: 0.1698 - val_accuracy: 0.8281 - val_loss: 0.4854
# Epoch 28/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9586 - loss: 0.1630 - val_accuracy: 0.8219 - val_loss: 0.4891
# Epoch 29/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9617 - loss: 0.1570 - val_accuracy: 0.8188 - val_loss: 0.4933
# Epoch 30/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9641 - loss: 0.1510 - val_accuracy: 0.8250 - val_loss: 0.4955
# Epoch 31/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9680 - loss: 0.1451 - val_accuracy: 0.8250 - val_loss: 0.4993
# Epoch 32/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9695 - loss: 0.1398 - val_accuracy: 0.8281 - val_loss: 0.5025
# Epoch 33/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9727 - loss: 0.1346 - val_accuracy: 0.8250 - val_loss: 0.5039
# Epoch 34/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9734 - loss: 0.1295 - val_accuracy: 0.8219 - val_loss: 0.5075
# Epoch 35/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9734 - loss: 0.1245 - val_accuracy: 0.8250 - val_loss: 0.5117
# Epoch 36/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9742 - loss: 0.1202 - val_accuracy: 0.8219 - val_loss: 0.5153
# Epoch 37/100
# 40/40 - 0s - 3ms/step - accuracy: 0.9758 - loss: 0.1156 - val_accuracy: 0.8219 - val_loss: 0.5193
# Epoch 38/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9773 - loss: 0.1113 - val_accuracy: 0.8250 - val_loss: 0.5237
# Epoch 39/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9789 - loss: 0.1067 - val_accuracy: 0.8250 - val_loss: 0.5287
# Epoch 40/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9805 - loss: 0.1029 - val_accuracy: 0.8281 - val_loss: 0.5310
# Epoch 41/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9820 - loss: 0.0986 - val_accuracy: 0.8281 - val_loss: 0.5346
# Epoch 42/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9844 - loss: 0.0947 - val_accuracy: 0.8250 - val_loss: 0.5391
# Epoch 43/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9859 - loss: 0.0908 - val_accuracy: 0.8219 - val_loss: 0.5441
# Epoch 44/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9859 - loss: 0.0870 - val_accuracy: 0.8250 - val_loss: 0.5495
# Epoch 45/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9859 - loss: 0.0838 - val_accuracy: 0.8250 - val_loss: 0.5547
# Epoch 46/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9875 - loss: 0.0800 - val_accuracy: 0.8250 - val_loss: 0.5599
# Epoch 47/100
# 40/40 - 0s - 3ms/step - accuracy: 0.9875 - loss: 0.0770 - val_accuracy: 0.8281 - val_loss: 0.5657
# Epoch 48/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9891 - loss: 0.0736 - val_accuracy: 0.8281 - val_loss: 0.5718
# Epoch 49/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9898 - loss: 0.0707 - val_accuracy: 0.8281 - val_loss: 0.5768
# Epoch 50/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9898 - loss: 0.0674 - val_accuracy: 0.8313 - val_loss: 0.5837
# Epoch 51/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9898 - loss: 0.0646 - val_accuracy: 0.8313 - val_loss: 0.5902
# Epoch 52/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9906 - loss: 0.0620 - val_accuracy: 0.8281 - val_loss: 0.5958
# Epoch 53/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9922 - loss: 0.0591 - val_accuracy: 0.8313 - val_loss: 0.6014
# Epoch 54/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9930 - loss: 0.0568 - val_accuracy: 0.8313 - val_loss: 0.6080
# Epoch 55/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9937 - loss: 0.0542 - val_accuracy: 0.8344 - val_loss: 0.6131
# Epoch 56/100
# 40/40 - 0s - 7ms/step - accuracy: 0.9953 - loss: 0.0518 - val_accuracy: 0.8281 - val_loss: 0.6202
# Epoch 57/100
# 40/40 - 0s - 3ms/step - accuracy: 0.9953 - loss: 0.0494 - val_accuracy: 0.8313 - val_loss: 0.6245
# Epoch 58/100
# 40/40 - 0s - 3ms/step - accuracy: 0.9969 - loss: 0.0472 - val_accuracy: 0.8250 - val_loss: 0.6317
# Epoch 59/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9984 - loss: 0.0450 - val_accuracy: 0.8250 - val_loss: 0.6369
# Epoch 60/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9984 - loss: 0.0428 - val_accuracy: 0.8281 - val_loss: 0.6440
# Epoch 61/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9984 - loss: 0.0407 - val_accuracy: 0.8281 - val_loss: 0.6498
# Epoch 62/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9984 - loss: 0.0388 - val_accuracy: 0.8281 - val_loss: 0.6568
# Epoch 63/100
# 40/40 - 0s - 7ms/step - accuracy: 0.9984 - loss: 0.0369 - val_accuracy: 0.8313 - val_loss: 0.6619
# Epoch 64/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9992 - loss: 0.0352 - val_accuracy: 0.8313 - val_loss: 0.6698
# Epoch 65/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9992 - loss: 0.0335 - val_accuracy: 0.8313 - val_loss: 0.6755
# Epoch 66/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9992 - loss: 0.0318 - val_accuracy: 0.8281 - val_loss: 0.6826
# Epoch 67/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9992 - loss: 0.0304 - val_accuracy: 0.8281 - val_loss: 0.6878
# Epoch 68/100
# 40/40 - 0s - 4ms/step - accuracy: 0.9992 - loss: 0.0290 - val_accuracy: 0.8281 - val_loss: 0.6952
# Epoch 69/100
# 40/40 - 0s - 7ms/step - accuracy: 0.9992 - loss: 0.0274 - val_accuracy: 0.8281 - val_loss: 0.7021
# Epoch 70/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0263 - val_accuracy: 0.8250 - val_loss: 0.7081
# Epoch 71/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0250 - val_accuracy: 0.8250 - val_loss: 0.7155
# Epoch 72/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0240 - val_accuracy: 0.8250 - val_loss: 0.7221
# Epoch 73/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0228 - val_accuracy: 0.8250 - val_loss: 0.7294
# Epoch 74/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0218 - val_accuracy: 0.8250 - val_loss: 0.7352
# Epoch 75/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0208 - val_accuracy: 0.8281 - val_loss: 0.7434
# Epoch 76/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0199 - val_accuracy: 0.8281 - val_loss: 0.7484
# Epoch 77/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.8250 - val_loss: 0.7549
# Epoch 78/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0182 - val_accuracy: 0.8250 - val_loss: 0.7617
# Epoch 79/100
# 40/40 - 0s - 3ms/step - accuracy: 1.0000 - loss: 0.0174 - val_accuracy: 0.8250 - val_loss: 0.7660
# Epoch 80/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0166 - val_accuracy: 0.8250 - val_loss: 0.7741
# Epoch 81/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0160 - val_accuracy: 0.8281 - val_loss: 0.7800
# Epoch 82/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0153 - val_accuracy: 0.8313 - val_loss: 0.7869
# Epoch 83/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0147 - val_accuracy: 0.8281 - val_loss: 0.7913
# Epoch 84/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.8281 - val_loss: 0.7982
# Epoch 85/100
# 40/40 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.8313 - val_loss: 0.8048
# Epoch 86/100
# 40/40 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0129 - val_accuracy: 0.8281 - val_loss: 0.8107
# Epoch 87/100
# 40/40 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.8313 - val_loss: 0.8167
# Epoch 88/100
# 40/40 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 0.8281 - val_loss: 0.8225
# Epoch 89/100
# 40/40 - 1s - 15ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.8313 - val_loss: 0.8275
# Epoch 90/100
# 40/40 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.8250 - val_loss: 0.8346
# Epoch 91/100
# 40/40 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.8313 - val_loss: 0.8399
# Epoch 92/100
# 40/40 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.8313 - val_loss: 0.8452
# Epoch 93/100
# 40/40 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.8344 - val_loss: 0.8520
# Epoch 94/100
# 40/40 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.8281 - val_loss: 0.8566
# Epoch 95/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.8344 - val_loss: 0.8631
# Epoch 96/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.8281 - val_loss: 0.8679
# Epoch 97/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.8344 - val_loss: 0.8734
# Epoch 98/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.8344 - val_loss: 0.8785
# Epoch 99/100
# 40/40 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.8281 - val_loss: 0.8859
# Epoch 100/100
# 40/40 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.8344 - val_loss: 0.8895
# Training abgeschlossen: 100 Epochen, batch_size=32

# %% [markdown]
# ## 6. Lernkurven vergleichen (Train UND Val)
#
# **Legende:**
# - **Blau** = kleines Netz | **Orange** = tiefes Netz
# - **Gestrichelt** = Trainingsdaten | **Durchgezogen** = Validierungsdaten
#
# **Worauf achten?**
#
# | Muster | Diagnose |
# |---|---|
# | Train und Val sinken parallel | Gute Generalisierung |
# | Grosser Abstand Train vs. Val | Overfitting |
# | Val-Loss steigt, Train-Loss sinkt | Klares Overfitting-Signal |
# | Beide Kurven stagnieren frueh | Underfitting / zu wenig Kapazitaet |

# %%
hist_small = pd.DataFrame(history_small.history)
hist_deep  = pd.DataFrame(history_deep.history)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# --- Loss ---
axes[0].plot(hist_small['loss'],     color='steelblue', linestyle='--', linewidth=1.5, label='Klein - Train')
axes[0].plot(hist_small['val_loss'], color='steelblue', linestyle='-',  linewidth=2,   label='Klein - Val')
axes[0].plot(hist_deep['loss'],      color='orange',    linestyle='--', linewidth=1.5, label='Tief  - Train')
axes[0].plot(hist_deep['val_loss'],  color='orange',    linestyle='-',  linewidth=2,   label='Tief  - Val')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].set_title('Lernkurven: Loss', fontweight='bold')
axes[0].legend(fontsize=9)
axes[0].grid(True, alpha=0.4)

# --- Accuracy ---
axes[1].plot(hist_small['accuracy'],     color='steelblue', linestyle='--', linewidth=1.5, label='Klein - Train')
axes[1].plot(hist_small['val_accuracy'], color='steelblue', linestyle='-',  linewidth=2,   label='Klein - Val')
axes[1].plot(hist_deep['accuracy'],      color='orange',    linestyle='--', linewidth=1.5, label='Tief  - Train')
axes[1].plot(hist_deep['val_accuracy'],  color='orange',    linestyle='-',  linewidth=2,   label='Tief  - Val')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].set_title('Lernkurven: Accuracy', fontweight='bold')
axes[1].legend(fontsize=9)
axes[1].grid(True, alpha=0.4)

plt.suptitle(
    'Vergleich: Kleines Netz (blau) vs. Tiefes Netz (orange)\n'
    'gestrichelt = Train | durchgezogen = Val',
    fontsize=11, fontweight='bold'
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analyse der Ergebnisse
#
# ---
#
# ### Was die Kurven zeigen
#
# **Tiefes Netz (orange) — klassisches Overfitting:**
# ```
# Train-Accuracy:  → 100%    (orange gestrichelt steigt auf 1.0)
# Val-Accuracy:    →  83%    (orange durchgezogen stagniert)
# Train-Loss:      →   ~0    (sinkt gegen 0)
# Val-Loss:        →  0.9+   (steigt ab Epoche ~15 stark an)
# ```
# Das ist ein **Lehrbuchbeispiel für Overfitting** — Train-Loss sinkt auf fast 0, Val-Loss steigt gleichzeitig stark. Das Modell lernt die Trainingsdaten auswendig.
#
# **Kleines Netz (blau) — stabile Generalisierung:**
# ```
# Train-Accuracy:  →  88%    (blau gestrichelt)
# Val-Accuracy:    →  81%    (blau durchgezogen, stabil)
# Train-Loss:      →  0.25   (sinkt noch leicht)
# Val-Loss:        →  0.50   (stabil, kein Anstieg)
# ```
# Kein Overfitting — Train und Val laufen parallel. Aber: das Modell hat nicht die Kapazität die volle Struktur der Daten zu lernen.

# %% [markdown]
# ## 7. Testdaten-Evaluation

# %%
y_pred_small = np.argmax(model_small.predict(X_test_scaled, verbose=0), axis=1)
y_pred_deep  = np.argmax(model_deep.predict(X_test_scaled,  verbose=0), axis=1)
y_true       = np.argmax(y_test, axis=1)

acc_small = accuracy_score(y_true, y_pred_small)
acc_deep  = accuracy_score(y_true, y_pred_deep)

results = pd.DataFrame({
    'Modell':        ['Kleines Netz (1 Hidden Layer)', 'Tiefes Netz (2 Hidden Layers)'],
    'Parameter':     [model_small.count_params(), model_deep.count_params()],
    'Test-Accuracy': [round(acc_small, 4), round(acc_deep, 4)]
})
print(results.to_string(index=False))

# Barplot
fig, ax = plt.subplots(figsize=(7, 4))
bars = ax.bar(
    ['Kleines Netz\n(1 Hidden Layer, ~387 Params)',
     'Tiefes Netz\n(2 Hidden Layers, ~3523 Params)'],
    [acc_small, acc_deep],
    color=['steelblue', 'orange'], width=0.4
)
for bar, acc in zip(bars, [acc_small, acc_deep]):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.003,
            f'{acc:.4f}', ha='center', fontsize=12, fontweight='bold')
ax.set_ylim(0.5, 1.05)
ax.set_ylabel('Test-Accuracy')
ax.set_title('Accuracy-Vergleich auf Testdaten', fontweight='bold')
ax.grid(axis='y', alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
#                        Modell  Parameter  Test-Accuracy
# Kleines Netz (1 Hidden Layer)        387         0.8050
# Tiefes Netz (2 Hidden Layers)       3523         0.8275

# %% [markdown]
# ### Test-Accuracy Vergleich
#
# | Modell | Parameter | Test-Accuracy |
# |---|---|---|
# | Kleines Netz | 387 | 0.8050 |
# | Tiefes Netz | 3523 | **0.8275** |
#
# Das tiefe Netz ist trotz starkem Overfitting **2.25 Prozentpunkte besser** — weil es mehr Struktur aus den Daten extrahiert hat, auch wenn es gleichzeitig Rauschen lernt.
#
# ---

# %% [markdown]
# ## 8. Konfusionsmatrizen beider Modelle

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for ax, y_pred, title in zip(
    axes,
    [y_pred_small, y_pred_deep],
    [f'Kleines Netz (Acc={acc_small:.3f})', f'Tiefes Netz (Acc={acc_deep:.3f})']
):
    cm_val = confusion_matrix(y_true, y_pred)
    ConfusionMatrixDisplay(
        confusion_matrix=cm_val,
        display_labels=class_names
    ).plot(ax=ax, colorbar=False, cmap='Blues')
    ax.set_title(title, fontweight='bold')

plt.suptitle('Konfusionsmatrizen: Kleines vs. Tiefes Netz',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Fazit
#
# - Ein tieferes Netz hat mehr **Modellkapazitaet** – messbar durch die Parameteranzahl.
# - Auf einem komplexen Datensatz (20 Features, 3 Klassen, 2 Cluster)
#   zeigt sich dieser Vorteil als **messbar hoehere Accuracy**.
# - Die **Lernkurven (Train + Val)** zeigen mehr als die finale Accuracy:
#   ein grosser Abstand zwischen beiden Kurven signalisiert Overfitting.
# - **Mehr Kapazitaet hilft**, wenn Aufgabe komplex und genuegend Daten vorhanden.
# - **Mehr Kapazitaet schadet**, wenn Datensatz zu klein –
#   das Modell lernt Rauschen statt Struktur.
# - **Datensatzgroesse:** Fuer aussagekraeftige Lernkurven braucht man
#   mindestens ~300 Validierungssamples. Bei Iris (24 Val-Samples)
#   sind die Kurven zu rauschig fuer diesen Vergleich.
#
# > **Kernbotschaft:** Die richtige Modellgroesse haengt immer von
# > Datensatzgroesse und Aufgabenkomplexitaet ab.
# > Lernkurven sind das wichtigste Werkzeug zur Diagnose.

# %% [markdown]
# ### Didaktische Bewertung
#
#
# **1. Overfitting ist sichtbar** — Val-Loss steigt, während Train-Loss sinkt. Klarer geht es nicht.
#
# **2. Overfitting bedeutet nicht automatisch "schlechter"** — Das overfittende Modell hat trotzdem eine höhere Test-Accuracy. Das ist eine wichtige Nuance: ein Modell kann overfitting zeigen und trotzdem das bessere Modell sein.
#
# **3. Parameter und Accuracy skalieren nicht linear** — 9× mehr Parameter bringen nur 2.25% mehr Accuracy. Das motiviert direkt die nächste Frage:
#
# > Kann man die Kapazität des tiefen Netzes behalten, aber das Overfitting reduzieren?
#
# Die Antwort ist **Dropout** — und damit ist der Übergang zu K09_02 perfekt motiviert.
