# %% [markdown]
# # K04 02 Lineare Regression Uebung
#
# **Studentenversion**
#
# Bearbeiten Sie das Notebook Schritt für Schritt. Versuchen Sie, die kurzen Reflexionsfragen jeweils in eigenen Worten zu beantworten.

# %% [markdown]
# # Übung: Erstelle ein lineares Regressions-Modell

# %% [markdown]
# ## 0. Die Übungs-Daten vorbereiten

# %%
import matplotlib.pyplot as plt
import numpy as np

# Erstellt einen Zufallszahlengenerator von NumPy mit einem festen Startwert (Seed).
# Dadurch sind die Ergebnisse reproduzierbar
rng = np.random.RandomState(42)

# Erzeugt 50 unabhängige Stichproben aus einer Gleichverteilung im Intervall (0,10)
x = 10 * rng.rand(50)

# Erzeugt die Zielvariable gemäß dem linearen Modell y = 2 * x − 1 + ε
# Gerade mit der Steigung 2 und dem y-Achsenabschnitt -1
y = 2 * x - 1 + rng.randn(50)

plt.scatter(x, y)

# %% [markdown]
# ## 1. Eine Modellklasse auswählen und initialisieren

# %%
from sklearn.linear_model import LinearRegression

# TODO:
# Initialisieren Sie hier ein lineares Regressionsmodell.
model = ...

# %% [markdown]
# ## 2. Die Daten in einer Feature-Matrix und einem Zielvektor speichern

# %%
# TODO:
# Speichern Sie die Eingabedaten in einer Feature-Matrix X
# und die Zielwerte in einem Zielvektor y.
# Denken Sie daran: X muss in scikit-learn zweidimensional sein.

X = ...
y = ...

# %% [markdown]
# ## 3. Das Modell trainieren anhand der Trainingsdaten

# %%
# TODO:
# Trainieren Sie das Modell mit fit(...)
...

# %% [markdown]
# ## 4. Prognose

# %%
# TODO:
# Berechnen Sie Vorhersagen für x_test
# und visualisieren Sie Regressionsgerade und Datenpunkte.

# %% [markdown]
# ## 5. Das Bestimmtheitsmaß berechnen

# %%
from sklearn.metrics import r2_score

# TODO:
# Berechnen Sie den R²-Wert für die Trainingsdaten
# und interpretieren Sie ihn anschließend kurz in Worten.

# %% [markdown]
# Das **Bestimmtheitsmaß (R²)** ist eine wichtige Metrik in der linearen Regression, die angibt, wie gut das Modell die Varianz der abhängigen Variable (y) vorhersagen kann.
#
# Der Wert liegt immer zwischen 0 und 1 (oder 0 % und 100 %).
#
# Ein R²-Wert von 0.9749 bedeutet, dass etwa 97,49 % der Variabilität in den abhängigen Werten (y) durch das lineare Regressionsmodell erklärt werden kann.
#
# Das ist ein sehr hoher Wert, der darauf hindeutet, dass das Modell die Daten sehr gut anpasst.

# %% [markdown]
# ## Reflexion
#
# 1. Warum muss `X` für scikit-learn meist **zweidimensional** sein?
# 2. Was sagt ein hoher **R²-Wert** hier aus?
# 3. Woran würden Sie erkennen, dass das Modell nicht gut passt?
